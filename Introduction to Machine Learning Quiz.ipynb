# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Odunayo Grace/Desktop/Backup files/Desktop/2024 GROWTH/HAMOYE DATA SCIENCE INTERNSHIP_Must_complete/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = "latin-1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#Q2
df.groupby("Item").sum()
# Out:
#                      Area Code  \
# Item
# Alcohol, Non-Food        38447
# Alcoholic Beverages      75016
# Animal Products          18060
# Animal fats              85279
# Apples and products      69280
# ...                        ...
# Vegetables, Other        77779
# Vegetal Products         18060
# Wheat and products       87073
# Wine                     66206
# Yams                     50798
#
#                                                                   Area  \
# Item
# Alcohol, Non-Food    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAngo...
# Alcoholic Beverages  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Animal Products      AlgeriaAlgeriaAlgeriaAngolaAngolaAngolaBeninBe...
# Animal fats          AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Apples and products  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...                                                                ...
# ...

# %%
#Q3
my_data = df.groupby("Area")["Y2017"].sum()

# %%
my_data
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
#Q4
#total number of null
total_null = df["Y2014"].isnull().sum()
total_null
# Out:
# 1589

# %%
#percentage of null
total_value = len(df["Y2014"])
print(total_value)
percent_null = (total_null/total_value) * 100
print(percent_null)
# Out:
# 60943
# 2.6073544131401474

# %%
#Q5
#df.groupby("Area")["Element"].count()

# %%
#Q7
df.shape
# Out:
# (60943, 12)

# %%
#Q8
#df.corr(["Y2014", "Y2015", "Y2016", "Y2017"], "Element code")

# %%
#Q9
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#Q11
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 2
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Q14 & Q20
df.groupby("Element").sum()
# Out:
#                                         Area Code  \
# Element
# Domestic supply quantity                   708993
# Export Quantity                            599910
# Fat supply quantity (g/capita/day)         675050
# Feed                                       176272
# Food                                       663295
# Food supply (kcal/capita/day)              674057
# Food supply quantity (kg/capita/yr)        658446
# Import Quantity                            688174
# Losses                                     274353
# Other uses (non-food)                      235554
# Processing                                 271940
# Production                                 526751
# Protein supply quantity (g/capita/day)     675050
# Residuals                                  623271
# Seed                                       103537
# Stock Variation                            571566
# Total Population - Both sexes                6020
# ...

# %%
#unique country Q18
df["Area"].nunique()
# Out:
# 49
